# %%
# %sql
-- instacart.instacart_raw.aisles validation
SELECT
    'aisles' AS table_name,
    COUNT(*) AS total_rows,
    COUNT(*) - COUNT(DISTINCT aisle_id) AS duplicate_aisle_id_count,

    -- Exact NULL counts
    SUM(CASE
            WHEN aisle_id IS NULL THEN 1
            ELSE 0
        END) AS aisle_id_null_count,
    SUM(CASE
            WHEN aisle IS NULL THEN 1
            ELSE 0
        END) AS aisle_null_count,

    -- NULL Percentages
    ROUND(100.0 * SUM(CASE
            WHEN aisle_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS aisle_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN aisle IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS aisle_null_pct
FROM instacart.instacart_raw.aisles;

# %%
# %sql
-- instacart.instacart_raw.departments validation
SELECT
    'departments' AS table_name,
    COUNT(*) AS total_rows,
    COUNT(*) - COUNT(DISTINCT department_id) AS duplicate_department_id_count,

    -- Exact NULL counts
    SUM(CASE
            WHEN department_id IS NULL THEN 1
            ELSE 0
        END) AS department_id_null_count,
    SUM(CASE
            WHEN department IS NULL THEN 1
            ELSE 0
        END) AS department_null_count,

    -- NULL Percentages
    ROUND(100.0 * SUM(CASE
            WHEN department_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS department_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN department IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS department_null_pct
FROM instacart.instacart_raw.departments;

# %%
# %sql
-- instacart.instacart_raw.products validation
SELECT
    'products' AS table_name,
    COUNT(*) AS total_rows,
    COUNT(*) - COUNT(DISTINCT product_id) AS duplicate_product_id_count,

    -- Exact NULL counts
    SUM(CASE
            WHEN product_id IS NULL THEN 1
            ELSE 0
        END) AS product_id_null_count,
    SUM(CASE
            WHEN product_name IS NULL THEN 1
            ELSE 0
        END) AS product_name_null_count,
    SUM(CASE
            WHEN aisle_id IS NULL THEN 1
            ELSE 0
        END) AS aisle_id_null_count,
    SUM(CASE
            WHEN department_id IS NULL THEN 1
            ELSE 0
        END) AS department_id_null_count,

    -- NULL Percentages
    ROUND(100.0 * SUM(CASE
            WHEN product_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS product_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN product_name IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS product_name_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN aisle_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS aisle_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN department_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS department_id_null_pct
FROM instacart.instacart_raw.products;

# %%
# %sql
-- instacart.instacart_raw.orders validation
SELECT
    'orders' AS table_name,
    COUNT(*) AS total_rows,
    COUNT(*) - COUNT(DISTINCT order_id) AS duplicate_order_id_count,

    -- Exact NULL counts
    SUM(CASE
            WHEN order_id IS NULL THEN 1
            ELSE 0
        END) AS order_id_null_count,
    SUM(CASE
            WHEN user_id IS NULL THEN 1
            ELSE 0
        END) AS user_id_null_count,
    SUM(CASE
            WHEN eval_set IS NULL THEN 1
            ELSE 0
        END) AS eval_set_null_count,
    SUM(CASE
            WHEN order_number IS NULL THEN 1
            ELSE 0
        END) AS order_number_null_count,
    SUM(CASE
            WHEN order_dow IS NULL THEN 1
            ELSE 0
        END) AS order_dow_null_count,
    SUM(CASE
            WHEN order_hour_of_day IS NULL THEN 1
            ELSE 0
        END) AS order_hour_null_count,
    SUM(CASE
            WHEN days_since_prior_order IS NULL THEN 1
            ELSE 0
        END) AS days_since_prior_order_null_count,

    -- NULL Percentages
    ROUND(100.0 * SUM(CASE
            WHEN order_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS order_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN user_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS user_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN eval_set IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS eval_set_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN order_number IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS order_number_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN order_dow IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS order_dow_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN order_hour_of_day IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS order_hour_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN days_since_prior_order IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS days_since_prior_order_null_pct
FROM instacart.instacart_raw.orders;

# %%
# %sql
-- instacart.instacart_raw.order_products_prior validation
SELECT
    'order_products_prior' AS table_name,
    COUNT(*) AS total_rows,

    -- Exact NULL counts
    SUM(CASE
            WHEN order_id IS NULL THEN 1
            ELSE 0
        END) AS order_id_null_count,
    SUM(CASE
            WHEN product_id IS NULL THEN 1
            ELSE 0
        END) AS product_id_null_count,
    SUM(CASE
            WHEN add_to_cart_order IS NULL THEN 1
            ELSE 0
        END) AS add_to_cart_order_null_count,
    SUM(CASE
            WHEN reordered IS NULL THEN 1
            ELSE 0
        END) AS reordered_null_count,

    -- NULL Percentages
    ROUND(100.0 * SUM(CASE
            WHEN order_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS order_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN product_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS product_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN add_to_cart_order IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS add_to_cart_order_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN reordered IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS reordered_null_pct
FROM instacart.instacart_raw.order_products_prior;

# %%
# %sql
SELECT
    order_id,
    product_id,
    COUNT(*) AS duplicate_count
FROM instacart.instacart_raw.order_products_prior
GROUP BY order_id, product_id
HAVING COUNT(*) > 1;

# %%
# %sql
-- instacart.instacart_raw.order_products_train validation
SELECT
    'order_products_train' AS table_name,
    COUNT(*) AS total_rows,

    -- Exact NULL counts
    SUM(CASE
            WHEN order_id IS NULL THEN 1
            ELSE 0
        END) AS order_id_null_count,
    SUM(CASE
            WHEN product_id IS NULL THEN 1
            ELSE 0
        END) AS product_id_null_count,
    SUM(CASE
            WHEN add_to_cart_order IS NULL THEN 1
            ELSE 0
        END) AS add_to_cart_order_null_count,
    SUM(CASE
            WHEN reordered IS NULL THEN 1
            ELSE 0
        END) AS reordered_null_count,

    -- NULL Percentages
    ROUND(100.0 * SUM(CASE
            WHEN order_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS order_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN product_id IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS product_id_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN add_to_cart_order IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS add_to_cart_order_null_pct,
    ROUND(100.0 * SUM(CASE
            WHEN reordered IS NULL THEN 1
            ELSE 0
        END) / COUNT(*), 2) AS reordered_null_pct
FROM instacart.instacart_raw.order_products_train;

# %%
# %sql
SELECT
    order_id,
    product_id,
    COUNT(*) AS duplicate_count
FROM instacart.instacart_raw.order_products_train
GROUP BY order_id, product_id
HAVING COUNT(*) > 1;
